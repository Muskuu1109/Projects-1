# %% [markdown]
# <a href="https://colab.research.google.com/github/Muskuu1109/Projects-1/blob/main/Myntra_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MYNTRA DATA ANALYSIS**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("Myntra dataset 11.xlsx")
df
# Out:
#      Product ID Category Sub-category Product Name Brand Name   Size  \
# 0         P0001    Women      Topwear     T-Shirts   Roadster     40
# 1         P0002    Women      Topwear     T-Shirts   Roadster     40
# 2         P0003    Women      Topwear     T-Shirts   Roadster     42
# 3         P0004    Women      Topwear     T-Shirts   Roadster     44
# 4         P0005    Women      Topwear     T-Shirts       Puma     38
# ...         ...      ...          ...          ...        ...    ...
# 3066      P3067     Kids     Footwear      Sandals     Campus  9-12M
# 3067      P3068     Kids     Footwear      Sandals     Campus  9-12M
# 3068      P3069     Kids     Footwear      Sandals     Campus   3-6M
# 3069      P3070     Kids     Footwear      Sandals     Campus   3-6M
# 3070      P3071     Kids     Footwear      Sandals     Campus   3-6M
#
#                Color  Ratings
# 0              Black        4
# 1               Blue        5
# 2              White        3
# ...

# %%
customers = pd.read_excel("Myntra dataset 11.xlsx" , sheet_name = "dim_customers")
customers
# Out:
#    Customer ID  Customer Age     City        State
# 0         C001            30   Mumbai  Maharashtra
# 1         C002            35   Mumbai  Maharashtra
# 2         C003            36   Mumbai  Maharashtra
# 3         C004            40     Pune  Maharashtra
# 4         C005            25     Pune  Maharashtra
# ..         ...           ...      ...          ...
# 95        C096            36  Jodhpur    Rajasthan
# 96        C097            37  Jodhpur    Rajasthan
# 97        C098            38  Udaipur    Rajasthan
# 98        C099            39  Udaipur    Rajasthan
# 99        C100            40  Udaipur    Rajasthan
#
# [100 rows x 4 columns]

# %%
orders = pd.read_excel("Myntra dataset 11.xlsx", sheet_name = "fact_orders")
orders
# Out:
#      Order ID Customer ID Product ID       Date  Original Price  Discount%
# 0      OD0001        C001      P0001 2022-04-21             349       0.30
# 1      OD0002        C002      P0001 2021-05-02             350       0.30
# 2      OD0003        C003      P0001 2022-06-14             351       0.30
# 3      OD0004        C004      P0001 2022-08-29             352       0.25
# 4      OD0005        C005      P0001 2022-12-05             353       0.25
# ...       ...         ...        ...        ...             ...        ...
# 3495   OD3496        C081      P3071 2021-07-05            1160       0.50
# 3496   OD3497        C082      P3071 2021-02-22            1467       0.50
# 3497   OD3498        C083      P3071 2021-01-15            1143       0.50
# 3498   OD3499        C084      P3071 2022-11-15            1714       0.50
# 3499   OD3500        C085      P3071 2021-01-05            1557       0.50
#
# [3500 rows x 6 columns]

# %%
products = df
products
# Out:
#      Product ID Category Sub-category Product Name Brand Name   Size  \
# 0         P0001    Women      Topwear     T-Shirts   Roadster     40
# 1         P0002    Women      Topwear     T-Shirts   Roadster     40
# 2         P0003    Women      Topwear     T-Shirts   Roadster     42
# 3         P0004    Women      Topwear     T-Shirts   Roadster     44
# 4         P0005    Women      Topwear     T-Shirts       Puma     38
# ...         ...      ...          ...          ...        ...    ...
# 3066      P3067     Kids     Footwear      Sandals     Campus  9-12M
# 3067      P3068     Kids     Footwear      Sandals     Campus  9-12M
# 3068      P3069     Kids     Footwear      Sandals     Campus   3-6M
# 3069      P3070     Kids     Footwear      Sandals     Campus   3-6M
# 3070      P3071     Kids     Footwear      Sandals     Campus   3-6M
#
#                Color  Ratings
# 0              Black        4
# 1               Blue        5
# 2              White        3
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3071 entries, 0 to 3070
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product ID    3071 non-null   object
#  1   Category      3071 non-null   object
#  2   Sub-category  3071 non-null   object
#  3   Product Name  3071 non-null   object
#  4   Brand Name    3071 non-null   object
#  5   Size          3071 non-null   object
#  6   Color         3071 non-null   object
#  7   Ratings       3071 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 192.1+ KB

# %%
#Check for duplicates

products.duplicated().sum()
customers.duplicated().sum()
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.drop_duplicates()
# Out:
#      Product ID Category Sub-category Product Name Brand Name   Size  \
# 0         P0001    Women      Topwear     T-Shirts   Roadster     40
# 1         P0002    Women      Topwear     T-Shirts   Roadster     40
# 2         P0003    Women      Topwear     T-Shirts   Roadster     42
# 3         P0004    Women      Topwear     T-Shirts   Roadster     44
# 4         P0005    Women      Topwear     T-Shirts       Puma     38
# ...         ...      ...          ...          ...        ...    ...
# 3066      P3067     Kids     Footwear      Sandals     Campus  9-12M
# 3067      P3068     Kids     Footwear      Sandals     Campus  9-12M
# 3068      P3069     Kids     Footwear      Sandals     Campus   3-6M
# 3069      P3070     Kids     Footwear      Sandals     Campus   3-6M
# 3070      P3071     Kids     Footwear      Sandals     Campus   3-6M
#
#                Color  Ratings
# 0              Black        4
# 1               Blue        5
# 2              White        3
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Customer ID   100 non-null    object
#  1   Customer Age  100 non-null    int64
#  2   City          100 non-null    object
#  3   State         100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
customers.isnull().sum()
# Out:
# Customer ID     0
# Customer Age    0
# City            0
# State           0
# dtype: int64

# %%
customers.dropna(axis = 0, inplace=True)
customers.isnull().sum()
# Out:
# Customer ID     0
# Customer Age    0
# City            0
# State           0
# dtype: int64

# %%
orders.describe()
# Out:
#                                 Date  Original Price    Discount%
# count                           3500     3500.000000  3500.000000
# mean   2022-02-10 01:59:43.542857216      839.316857     0.355146
# min              2021-01-01 00:00:00      123.000000     0.100000
# 25%              2021-07-21 00:00:00      456.000000     0.300000
# 50%              2022-02-06 00:00:00      634.000000     0.350000
# 75%              2022-09-05 00:00:00     1119.000000     0.420000
# max              2023-03-31 00:00:00    22365.000000     0.550000
# std                              NaN      685.735929     0.100804

# %%
orders["Month"] = orders["Date"].dt.strftime("%B")
orders
# Out:
#      Order ID Customer ID Product ID       Date  Original Price  Discount%  \
# 0      OD0001        C001      P0001 2022-04-21             349       0.30
# 1      OD0002        C002      P0001 2021-05-02             350       0.30
# 2      OD0003        C003      P0001 2022-06-14             351       0.30
# 3      OD0004        C004      P0001 2022-08-29             352       0.25
# 4      OD0005        C005      P0001 2022-12-05             353       0.25
# ...       ...         ...        ...        ...             ...        ...
# 3495   OD3496        C081      P3071 2021-07-05            1160       0.50
# 3496   OD3497        C082      P3071 2021-02-22            1467       0.50
# 3497   OD3498        C083      P3071 2021-01-15            1143       0.50
# 3498   OD3499        C084      P3071 2022-11-15            1714       0.50
# 3499   OD3500        C085      P3071 2021-01-05            1557       0.50
#
#          Month
# 0        April
# 1          May
# 2         June
# ...

# %%
orders["Total Price"] = orders["Original Price"] - (orders["Original Price"] * orders["Discount%"])
orders
# Out:
#      Order ID Customer ID Product ID       Date  Original Price  Discount%  \
# 0      OD0001        C001      P0001 2022-04-21             349       0.30
# 1      OD0002        C002      P0001 2021-05-02             350       0.30
# 2      OD0003        C003      P0001 2022-06-14             351       0.30
# 3      OD0004        C004      P0001 2022-08-29             352       0.25
# 4      OD0005        C005      P0001 2022-12-05             353       0.25
# ...       ...         ...        ...        ...             ...        ...
# 3495   OD3496        C081      P3071 2021-07-05            1160       0.50
# 3496   OD3497        C082      P3071 2021-02-22            1467       0.50
# 3497   OD3498        C083      P3071 2021-01-15            1143       0.50
# 3498   OD3499        C084      P3071 2022-11-15            1714       0.50
# 3499   OD3500        C085      P3071 2021-01-05            1557       0.50
#
#          Month  Total Price
# 0        April       244.30
# ...

# %%
gb = orders.groupby("Month").agg({"Total Price":"sum"})
gb
# Out:
#            Total Price
# Month
# April        134911.03
# August       129757.70
# December     129980.90
# February     201099.01
# January      239115.62
# July         150661.21
# June         147667.68
# March        213186.80
# May          143356.76
# November     134301.93
# October      126098.64
# September    130668.54

# %%
#plt.figure(figsize = (12,4))
sns.barplot(x = gb.index, y = gb["Total Price"], order = ["January", "February", "March",'April',"May","June","July","August","September","October","November", "December"],hue = gb.index, palette = "GnBu")
plt.xticks(rotation = 45)
plt.show()

# %%
# Convert the 'Size' column to numeric, handling non-numeric values
products['Size'] = pd.to_numeric(products['Size'], errors='coerce')

# Group by 'Color' and calculate the sum of 'Size' (now numeric)
gb1 = products.groupby("Color").agg({"Size": "sum"})
gb1
# Out:
#                   Size
# Color
# Beige           3074.0
# Black           3356.0
# Black & White    350.0
# Blue            2404.0
# Brown           1896.0
# Burgundy         334.0
# Charcoal        1060.0
# Coffee Brown     134.0
# Copper           128.0
# Coral            216.0
# Cream           1328.0
# Gold             302.0
# Green           1030.0
# Green              0.0
# Grey            1146.0
# Khaki            862.0
# Lavender        1128.0
# Magenta          132.0
# Maroon           406.0
# Multicolor         0.0
# Mustard          458.0
# Navy Blue       1430.0
# Nude               0.0
# Off white       1906.0
# Olive            268.0
# Orange          1636.0
# Peach           1518.0
# Pink            2090.0
# Purple           918.0
# Red              586.0
# Red              146.0
# Rose             260.0
# Rust            1154.0
# Sea Green       1356.0
# Silver             0.0
# Skin             138.0
# Tan              164.0
# Teal            1712.0
# ...

# %%
sns.barplot(x=gb1.index, y=gb1["Size"], palette="viridis")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 8))
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=np.number)
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Category'], bins=30, kde=True)
plt.title('Product Name')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
if 'Sub-Category' in df.columns:
    sns.countplot(data=df, x='Brand Name', order=df['Sub-Category'].value_counts().index)
else:

    print("Column 'Sub-Category' not found in DataFrame. Using default order.")
    sns.countplot(data=df, x='Brand Name')

plt.title('Count of Products by Category')
plt.xticks(rotation=90)
plt.show()
# Out:
# Column 'Sub-Category' not found in DataFrame. Using default order.

# %%
total_original_price = orders['Original Price'].sum()
total_discount = orders['Total Price'].sum()

labels = ['Original Price', 'Discount']
sizes = [total_original_price, total_original_price-total_discount]
colors = ['skyblue', 'lightcoral']
explode = (0.1, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Original Price vs. Discount')

plt.show()

# %%
sns.violinplot(x='State', y='City', data=customers , palette='Set2')
plt.xlabel('State')
plt.ylabel('City')
plt.xticks(rotation=45)
plt.title('Distribution of City by State')
plt.show()

plt.show()

# %%
print(products.columns)
if 'Rating' not in products.columns:
    sns.boxplot(x="Color", y="Ratings", data=products, palette="inferno")

else:
    sns.boxplot(x="Color", y="Ratings", data=products, palette="inferno")

plt.xticks(rotation=90)
plt.show()
# Out:
# Index(['Product ID', 'Category', 'Sub-category', 'Product Name', 'Brand Name',
#        'Size', 'Color', 'Ratings'],
#       dtype='object')

# %%
sns.histplot(products['Ratings'], bins=10, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.show()

sns.scatterplot(x='Size', y='Ratings', data=products, hue='Color')
plt.title('Relationship between Size and Ratings')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
x = products['Category'].astype('category').cat.codes

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

x = products['Category'].astype('category').cat.codes
y = products['Size']
z = products['Ratings']


scatter = ax.scatter(x, y, z, c=z, cmap='cividis')

fig.colorbar(scatter)

plt.show()
