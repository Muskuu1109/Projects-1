# %% [markdown]
# <a href="https://colab.research.google.com/github/Muskuu1109/Projects-1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Crop_recommendation.csv')
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.ensemble import RandomForestClassifier # make sure to import the model
from sklearn.model_selection import train_test_split

# Split data into training and testing sets
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create and train the model
model = RandomForestClassifier() # Assign the model to a variable
model.fit(x_train, y_train) # train the model

# Now you can access feature_importances_
feature_importances = model.feature_importances_
feature_names = df.columns[:-1]  # Exclude the target variable column

# Create a DataFrame for visualization
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Assuming 'y_test' and 'predictions' are your test labels and model predictions
# Get model predictions
predictions = model.predict(x_test) # Define 'predictions' variable

cm = confusion_matrix(y_test, predictions)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'y_test' and 'predictions' are your test labels and model predictions
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.5)
plt.plot(np.unique(y_test), np.unique(y_test), color='red', linestyle='--')  # Diagonal line
plt.title('Actual vs. Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 1656   17  16  14    16.396243  92.181519  6.625539  102.944161
# 752    37  79  19    27.543848  69.347863  7.143943   69.408782
# 892     7  73  25    27.521856  63.132153  7.288057   45.208411
# 1041  101  70  48    25.360592  75.031933  6.012697  116.553145
# 1179    0  17  30    35.474783  47.972305  6.279134   97.790725

# %%
y_train.head()
# Out:
# 1656       orange
# 752     blackgram
# 892        lentil
# 1041       banana
# 1179        mango
# Name: label, dtype: object

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions=model.predict(x_test)

# %%
accuracy = model.score(x_test,y_test)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9931818181818182

# %%
new_features = [(36,58,25,28.66024,59.31891,8.399136,36.9263)]
predicted_crop = model.predict(new_features)
print("Predicted Crop:",predicted_crop[0])
# Out:
# Predicted Crop: mothbeans
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle
with open('crop_recommendation_model.pkl','wb') as f:
    pickle.dump(model,f)

# %%
import pickle
# Replace protocol=pickle.HIGHEST_PROTOCOL with the desired protocol version
with open('crop_recommendation_model.pkl','wb') as f:
    pickle.dump(model,f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
from google.colab import files
files.download("crop_recommendation_model.pkl") # Change "data.pkl" to "crop_recommendation_model.pkl"
